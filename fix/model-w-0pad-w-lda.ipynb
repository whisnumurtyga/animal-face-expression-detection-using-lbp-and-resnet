# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet101

from tensorflow.keras import layers, Model

# %%
working_path = "D:/Semester 5/MachineORDeep Learning/Final Project"
# file_names = ['encoded-dogcat-img-16.csv', 'encoded-dogcat-img-32.csv', 'encoded-dogcat-img-64.csv', 'encoded-dogcat-img-128.csv']
file_names = ['encoded-dogcat-img-32.csv']

lda = LinearDiscriminantAnalysis()

# %%
def model_def(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(50, input_shape=(input_shape,), activation='relu'),  # Layer input dengan 50 neuron
        tf.keras.layers.Dense(50, activation='relu'),  
        tf.keras.layers.Dense(4, activation='softmax') 
    ])
    return model

def model_dropout1(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(50, input_shape=(input_shape,), activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(50, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(4, activation='softmax')
    ])
    return model

def residual_block(input_tensor, filters):
    x = tf.keras.layers.Dense(filters, activation='relu')(input_tensor)
    x = tf.keras.layers.BatchNormalization()(x)

    # x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dense(filters, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    # Shortcut connection
    shortcut = tf.keras.layers.Dense(filters)(input_tensor)
    shortcut = tf.keras.layers.BatchNormalization()(shortcut)
    # Tambahkan shortcut ke output
    x = tf.keras.layers.Add()([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    return x

def resnet_tabular(input_shape):

    # Membuat model ResNet untuk data Iris
    input_shape = input_shape

    inputs = tf.keras.layers.Input(shape=(input_shape,))
    x = tf.keras.layers.Reshape((input_shape, 1))(inputs)  # Menambahkan dimensi untuk keperluan Conv1D

    x = residual_block(x, 64)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(4, activation='softmax')(x)  # Output layer dengan 3 kelas (Iris memiliki 3 kelas)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    return model


def set_callbacks(model_name):
    callbacks = [
    # Early stopping untuk menghentikan pelatihan jika tidak ada peningkatan dalam validasi setelah beberapa epoch
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    
    # ModelCheckpoint untuk menyimpan model dengan akurasi validasi terbaik
    ModelCheckpoint(f'../models-w-0pad-w-lda/{model_name}.h5', monitor='val_accuracy', save_best_only=True)
    ]
    return callbacks

def resnet_buPima(input_shape):
    inputs = tf.keras.layers.Input(shape=input_shape)  # Tambahkan layer input
    x = tf.expand_dims(inputs, axis=-1)  # Tambahkan dimensi keempat

    resnet_50 = tf.keras.applications.resnet50.ResNet50(include_top=False, weights=None)
    resnet_50.trainable = False

    x = resnet_50(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Flatten(name="flatten")(x)

    return tf.keras.Model(inputs=inputs, outputs=x)


def model_resnetBuPim(input_shape):
  model = resnet_buPima(input_shape)
  return model

# %%
models = []
train_accuracies = []
test_accuracies = []
train_loss_s = []
test_loss_s = []
histories = []



for i, f in enumerate(file_names):
    print(f"==> Start Model {file_names[i]} <==")
    
    # Load dataset
    df = pd.read_csv(f'{working_path}/dataset/dogcat-encode/{f}')
    df = df.iloc[:, 1:]
    # df = df.loc[:, (df != 0).any(axis=0)]


    X = df.iloc[:, :-1]
    y = df.iloc[:, -1:]

    # Linear Discriminant Analysis (LDA)
    lda = LinearDiscriminantAnalysis(n_components=min(X.shape[1], y.iloc[:, 0].nunique()-1))
    X_lda = lda.fit_transform(X, y)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X_lda, y, test_size=0.2, random_state=42)

    model_default = model_def(X_train.shape[1])
    model_resnet = resnet_tabular(X_train.shape[1])

    models.append(model_default)
    models.append(model_resnet)
    model_names = ['neural-network', 'neural-network-modificate']
    
    for k, mod in enumerate(models): 
        # Compile model
        mod.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        
        # Train model
        history = mod.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=set_callbacks(model_names[k]))
        test_loss, test_accuracy = mod.evaluate(X_test, y_test)


        # models.append(model)
        histories.append(history)

        last_accuracy = history.history['accuracy'][-1]
        train_accuracies.append(last_accuracy)
        test_accuracies.append(test_accuracy)
        train_loss_s.append(history.history['loss'][-1])
        test_loss_s.append(test_loss)

        print(f"==> End Model {file_names[i]} <==")
# Out:
# ==> Start Model encoded-dogcat-img-32.csv <==
# c:\ProgramData\anaconda3\envs\mdl\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/50
# 21/21 [==============================] - 1s 17ms/step - loss: 0.7874 - accuracy: 0.8419 - val_loss: 0.3474 - val_accuracy: 1.0000
# Epoch 2/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1966 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 3/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 4/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 5/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 6/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 7/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 8/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 9/50
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 10/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 11/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 12/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 13/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 14/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 15/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 16/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 17/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 18/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 19/50
# 21/21 [==============================] - 0s 6ms/step - loss: 9.8899e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 20/50
# 21/21 [==============================] - 0s 6ms/step - loss: 8.9696e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 21/50
# 21/21 [==============================] - 0s 7ms/step - loss: 8.1639e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 22/50
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4995e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 23/50
# 21/21 [==============================] - 0s 5ms/step - loss: 6.8979e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 24/50
# 21/21 [==============================] - 0s 6ms/step - loss: 6.3525e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 25/50
# 21/21 [==============================] - 0s 6ms/step - loss: 5.8401e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 26/50
# 21/21 [==============================] - 0s 6ms/step - loss: 5.4003e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 27/50
# 21/21 [==============================] - 0s 5ms/step - loss: 4.9974e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 28/50
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6781e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 29/50
# 21/21 [==============================] - 0s 5ms/step - loss: 4.3888e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 30/50
# 21/21 [==============================] - 0s 5ms/step - loss: 4.1270e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 31/50
# 21/21 [==============================] - 0s 5ms/step - loss: 3.8881e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 32/50
# 21/21 [==============================] - 0s 6ms/step - loss: 3.6718e-04 - accuracy: 1.0000 - val_loss: 9.9103e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 21/21 [==============================] - 0s 6ms/step - loss: 3.4573e-04 - accuracy: 1.0000 - val_loss: 9.9256e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 21/21 [==============================] - 0s 5ms/step - loss: 3.2684e-04 - accuracy: 1.0000 - val_loss: 9.5604e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 21/21 [==============================] - 0s 4ms/step - loss: 3.0939e-04 - accuracy: 1.0000 - val_loss: 9.2113e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.9404e-04 - accuracy: 1.0000 - val_loss: 8.8362e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.7930e-04 - accuracy: 1.0000 - val_loss: 8.5845e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.6481e-04 - accuracy: 1.0000 - val_loss: 8.3395e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.5193e-04 - accuracy: 1.0000 - val_loss: 8.1926e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.3969e-04 - accuracy: 1.0000 - val_loss: 7.8756e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.2858e-04 - accuracy: 1.0000 - val_loss: 7.6428e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.1851e-04 - accuracy: 1.0000 - val_loss: 7.3802e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.0884e-04 - accuracy: 1.0000 - val_loss: 7.1345e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.9984e-04 - accuracy: 1.0000 - val_loss: 6.9252e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.9176e-04 - accuracy: 1.0000 - val_loss: 6.7285e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.8362e-04 - accuracy: 1.0000 - val_loss: 6.5415e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.7654e-04 - accuracy: 1.0000 - val_loss: 6.3311e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.6922e-04 - accuracy: 1.0000 - val_loss: 6.1507e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.6282e-04 - accuracy: 1.0000 - val_loss: 6.0885e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.5663e-04 - accuracy: 1.0000 - val_loss: 5.9096e-04 - val_accuracy: 1.0000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.9096e-04 - accuracy: 1.0000
# ==> End Model encoded-dogcat-img-32.csv <==
# Epoch 1/50
# 21/21 [==============================] - 5s 39ms/step - loss: 0.6751 - accuracy: 0.7550 - val_loss: 0.8401 - val_accuracy: 0.7346
# Epoch 2/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0787 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.9815
# Epoch 3/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0427 - accuracy: 0.9984 - val_loss: 0.3791 - val_accuracy: 0.9877
# Epoch 4/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0286 - accuracy: 0.9984 - val_loss: 0.2894 - val_accuracy: 0.9877
# Epoch 5/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9938
# Epoch 6/50
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 1.0000
# Epoch 7/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 1.0000
# Epoch 8/50
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 9/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 10/50
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 11/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 12/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 13/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 14/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 15/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 16/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 17/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 18/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 19/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 20/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 21/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 22/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 23/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 24/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 25/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 26/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 27/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 28/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 29/50
# 21/21 [==============================] - 0s 7ms/step - loss: 9.4172e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 30/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 31/50
# 21/21 [==============================] - 0s 7ms/step - loss: 7.1515e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 32/50
# 21/21 [==============================] - 0s 6ms/step - loss: 9.5051e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 33/50
# 21/21 [==============================] - 0s 11ms/step - loss: 8.4199e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 34/50
# 21/21 [==============================] - 0s 7ms/step - loss: 6.2597e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 35/50
# 21/21 [==============================] - 0s 7ms/step - loss: 7.6897e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 36/50
# 21/21 [==============================] - 0s 7ms/step - loss: 6.5505e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 37/50
# 21/21 [==============================] - 0s 8ms/step - loss: 6.8213e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 38/50
# 21/21 [==============================] - 0s 6ms/step - loss: 7.6050e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 39/50
# 21/21 [==============================] - 0s 7ms/step - loss: 9.2828e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 40/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 41/50
# 21/21 [==============================] - 0s 7ms/step - loss: 8.5344e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 42/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 43/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 44/50
# 21/21 [==============================] - 0s 7ms/step - loss: 6.2844e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# ==> End Model encoded-dogcat-img-32.csv <==

# %%
import numpy as np

# Mencari panjang maksimum dari histori
max_epochs = max([len(history.history['loss']) for history in histories])

# Plot loss
plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)  # Dua baris, satu kolom, plot pertama

for i, history in enumerate(histories):
    epochs = range(1, max_epochs + 1)  # Gunakan max_epochs di sini
    
    # Menyesuaikan panjang histori
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    padded_loss = np.pad(loss, (0, max_epochs - len(loss)), 'constant', constant_values=np.nan)
    padded_val_loss = np.pad(val_loss, (0, max_epochs - len(val_loss)), 'constant', constant_values=np.nan)
    
    plt.plot(epochs, padded_loss, label=f'{model_names[i]} - Training Loss')
    plt.plot(epochs, padded_val_loss, label=f'{model_names[i]} - Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot akurasi
plt.subplot(2, 1, 2)  # Dua baris, satu kolom, plot kedua

for i, history in enumerate(histories):
    epochs = range(1, max_epochs + 1)  # Gunakan max_epochs di sini
    
    # Menyesuaikan panjang histori
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    padded_accuracy = np.pad(accuracy, (0, max_epochs - len(accuracy)), 'constant', constant_values=np.nan)
    padded_val_accuracy = np.pad(val_accuracy, (0, max_epochs - len(val_accuracy)), 'constant', constant_values=np.nan)
    
    plt.plot(epochs, padded_accuracy, label=f'{model_names[i]} - Training Accuracy')
    plt.plot(epochs, padded_val_accuracy, label=f'{model_names[i]} - Validation Accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
res_nn_model = pd.DataFrame({
    'model': model_names,
    'train_loss': train_loss_s,
    'train_accuracy' : train_accuracies,
    'test_loss': test_loss_s,
    'test_accuracy' : test_accuracies,
})

res_nn_model.head()
# Out:
#                        model  train_loss  train_accuracy  test_loss  \
# 0             neural-network    0.000157             1.0   0.000591
# 1  neural-network-modificate    0.000628             1.0   0.003212
#
#    test_accuracy
# 0            1.0
# 1            1.0
